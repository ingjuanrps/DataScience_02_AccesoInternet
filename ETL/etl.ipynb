# %% [markdown]
# # ETL.

# %% [markdown]
# ## Importación de Librerias.

# %%
import pandas as pd
import  requests
import io

# %% [markdown]
# ## Cargando la URL y opteniendo respuesta del requests.

# %%
url='http://api.datosabiertos.enacom.gob.ar/api/v2/datastreams/TOTAL-NACIO-DE-ACCES-48866/data.csv/?auth_key=FFuyt2Q0gKtzvHGDXZwC3iXnWjXJuRbgOAJnUPDH'
# Solicitud
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# ## Instanciando reponse para leer el contenido del archivo en memoria como una cadena de texto.

# %%
# Leer el contenido del archivo CSV en memoria como una cadena de texto
datos = response.content.decode("utf-8")

# %% [markdown]
# ## Creando un DataFrame df con las instantancias anteriores y viendo su contenido.

# %%
df = pd.DataFrame(pd.read_csv(io.StringIO(datos), encoding="utf-8"))
df.head()
# Out:
#     Año  Trimestre  Banda ancha fija  Dial up  Total        Periodo
# 0  2022          4                11       12     11   Oct-Dic 2022
# 1  2022          3                11       12     11  Jul-Sept 2022
# 2  2022          2                11       12     11   Abr-Jun 2022
# 3  2022          1                11       13     11   Ene-Mar 2022
# 4  2021          4                10       13     10   Oct-Dic 2021

# %%
df.shape
# Out:
# (36, 6)

# %% [markdown]
# ## Guardando los resulatdos en un archivo csv.

# %%
df.to_csv(r'C:\Users\ingju\Desktop\JrPs_PI2\data\01_InternetPenetracion.csv')

# %% [markdown]
# ## Instanciando para crear un nuevo DataFrame con el archivo creado en csv.

# %%
AccesoInternet=pd.read_csv(r'C:\Users\ingju\Desktop\JrPs_PI2\data\Internet_Penetracion.csv')
AccesoInternet
# Out:
#      Anio  Trimestre  AnioTrimestre     Provincia  AccesoCada100Hogares  \
# 0    2022          4          20224  Buenos Aires                 78.94
# 1    2022          3          20223  Buenos Aires                 78.11
# 2    2022          2          20222  Buenos Aires                 77.58
# 3    2022          1          20221  Buenos Aires                 76.08
# 4    2021          4          20214  Buenos Aires                 75.66
# ..    ...        ...            ...           ...                   ...
# 859  2015          1          20151      TucumÃ¡n                 35.08
# 860  2014          4          20144      TucumÃ¡n                 35.32
# 861  2014          3          20143      TucumÃ¡n                 33.94
# 862  2014          2          20142      TucumÃ¡n                 33.94
# 863  2014          1          20141      TucumÃ¡n                 33.42
#
#      DiferenciaTrimestral  PorcientoTrimestral  Cumple2  BandAnchaFija  \
# ...

# %% [markdown]
# ## Observando el dimencionamineto del DataFrame.

# %%
AccesoInternet.shape
# Out:
# (864, 26)

# %%
AccesoInternet.columns
# Out:
# Index(['Anio', 'Trimestre', 'AnioTrimestre', 'Provincia',
#        'AccesoCada100Hogares', 'DiferenciaTrimestral', 'PorcientoTrimestral',
#        'Cumple2', 'BandAnchaFija', 'Dial_up', 'ADSL', 'Cablemodem',
#        'FibraOptica', 'Wireless', 'OtrosTipoConexion', 'totalServicios',
#        'Mbps(Media de bajada)', 'Hasta512kbps', '512Kbps_Menos1Mbps',
#        '1Mbps_Menos6Mbps', '6Mbps_Menos10Mbps', '10Mbps_Menos20Mbps',
#        '20Mbps_Menos30Mbps', '30Mbps', 'OtrosMbps', 'Total_Mbps'],
#       dtype='object')

# %% [markdown]
# Información de las columnas del dataframe.
#
# | *Columna* | *Descripción* |
# | --- | --- |
# | 	Año | Año de la toma de la información. |
# | Trimestre | Trimestre del año de la toma de la información. |
# | Provincia | Provincia del pais de Argentina donde fue tomada la información. |
# | AccesoCada100Hogares | Cantidad de Hogares por cada 100. |
# | BandAnchaFija | Servicio de acceso a Internet que brindan las empresas telefónicas utilizando el tráfico de datos con el mismo cable telefónico que para las transmisiones de voz, pero en bandas de frecuencias distintas, lo que permite el uso de ambos servicios en simultáneo. |
# | Dial_up | Las conexiones dial-up requieren que los usuarios vinculen su línea de teléfono a una computadora para acceder a Internet. |
# | ADSL |  (Asimetric Digital Subscriber Line o Línea de Abonado Digital Asimétrica) es una tecnología de módem que transforma las líneas telefónicas o el par de cobre del abonado en líneas de alta velocidad permanentemente establecidas y pagando una única cantidad mensual. |
# | Cablemodem | es un dispositivo instalado por el proveedor de servicios, diseñado para entregar el acceso a Internet de banda ancha. Se utilizan para ofrecer acceso a transmisión de datos e Internet de banda ancha utilizando la red desplegada originalmente para transportar la señal de televisión por cable (CATV). |
# | FibraOptica | es una guía de onda en forma de hilo de material altamente transparente diseñado para transmitir información a grandes distancias utilizando señales ópticas. |
# | Wireless | Inalámbrico. |
# | OtrosTipoConexión | Tipo de conexxiones no estipuladas en la información. |
# | totalServicios | Conteo de la información de todos los servicios optenidos.  |
# | Mbps(Media de bajada) | La velocidad de internet suele definirse en Mbps (megabits por segundo). |
# | Hasta512kbps | Velocidad de internet hasta 512 mkilobits por segundo. |
# | 512Kbps_Menos1Mbps | Velocidad a partir de 512 Kbps hasta 1 Mbps.
# | 1Mbps_Menos6Mbps | Velocidad a partir de 1 Mbps hasta 6 Mbps |
# | 6Mbps_Menos10Mbps | Velocidad a partir de 6 Mbps hasta 10 Mbps. |
# | 10Mbps_Menos20Mbps | Velocidad a partir de 10 Mbps hasta 20 Mbps. |
# | 20Mbps_Menos30Mbps | Velocidad a partir de 20 Mbps hasta 30 Mbps. |
# | 30Mbps | Velocidad mayor a 30 Mbps. |
# | OtrosMbps | Otros tipos de Megabits por segundo. |
# | Total_Mbps | Conteo de todos los Megas de velocidad. |

# %% [markdown]
# ## Analizamos los distintos tipos de datos por columna.

# %%
# Analizamos los distintos tipos de datos por columna.
for col in AccesoInternet.columns:
  print(AccesoInternet[col].unique())
# Out:
# [2022 2021 2020 2019 2018 2017 2016 2015 2014]
# [4 3 2 1]
# [20224 20223 20222 20221 20214 20213 20212 20211 20204 20203 20202 20201
#  20194 20193 20192 20191 20184 20183 20182 20181 20174 20173 20172 20171
#  20164 20163 20162 20161 20154 20153 20152 20151 20144 20143 20142 20141]
# ['Buenos Aires' 'CÃ³rdoba' 'Capital Federal' 'Catamarca' 'Chaco' 'Chubut'
#  'Corrientes' 'Entre RÃ\xados' 'Formosa' 'Jujuy' 'La Pampa' 'La Rioja'
#  'Mendoza' 'Misiones' 'NeuquÃ©n' 'RÃ\xado Negro' 'Salta' 'San Juan'
#  'San Luis' 'Santa Cruz' 'Santa Fe' 'Santiago Del Estero'
#  'Tierra Del Fuego' 'TucumÃ¡n']
# [ 78.94  78.11  77.58  76.08  75.66  71.68  70.    69.11  68.98  67.66
#   65.22  64.33  64.25  69.36  67.85  66.24  64.6   64.44  62.78  62.63
#   57.61  55.63  56.27  58.57  61.24  60.14  59.34  57.34  58.29  57.69
#   56.8   56.37  56.09  56.75  55.06  54.57  89.03  88.31  87.48  85.76
#   84.51  81.28  80.12  78.59  78.08  75.22  72.71  70.69  70.48  68.59
# ...

# %% [markdown]
# ## Información del DataFrame.

# %%
AccesoInternet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Anio                   864 non-null    int64
#  1   Trimestre              864 non-null    int64
#  2   AnioTrimestre          864 non-null    int64
#  3   Provincia              864 non-null    object
#  4   AccesoCada100Hogares   864 non-null    float64
#  5   DiferenciaTrimestral   864 non-null    float64
#  6   PorcientoTrimestral    864 non-null    float64
#  7   Cumple2                864 non-null    int64
#  8   BandAnchaFija          864 non-null    int64
#  9   Dial_up                862 non-null    float64
#  10  ADSL                   864 non-null    int64
#  11  Cablemodem             864 non-null    int64
#  12  FibraOptica            864 non-null    int64
#  13  Wireless               864 non-null    int64
# ...

# %% [markdown]
# ## Descripción del DataFrame.

# %%
AccesoInternet.describe()
# Out:
#               Anio   Trimestre  AnioTrimestre  AccesoCada100Hogares  \
# count   864.000000  864.000000     864.000000            864.000000
# mean   2018.000000    2.500000   20182.500000             49.620301
# std       2.583484    1.118682      25.859053             23.319150
# min    2014.000000    1.000000   20141.000000              9.350000
# 25%    2016.000000    1.750000   20161.750000             32.220000
# 50%    2018.000000    2.500000   20182.500000             46.390000
# 75%    2020.000000    3.250000   20203.250000             62.442500
# max    2022.000000    4.000000   20224.000000            124.060000
#
#        DiferenciaTrimestral  PorcientoTrimestral     Cumple2  BandAnchaFija  \
# count            864.000000           864.000000  864.000000     864.000000
# mean               1.917488             4.501273    0.322917     137.326389
# std                7.668396            17.615368    0.467862     180.812265
# ...

# %% [markdown]
# ## Observando valores únicos en la columna Provincia.

# %%
valoresUnicos = AccesoInternet['Provincia'].unique()
valoresUnicos
# Out:
# array(['Buenos Aires', 'CÃ³rdoba', 'Capital Federal', 'Catamarca',
#        'Chaco', 'Chubut', 'Corrientes', 'Entre RÃ\xados', 'Formosa',
#        'Jujuy', 'La Pampa', 'La Rioja', 'Mendoza', 'Misiones', 'NeuquÃ©n',
#        'RÃ\xado Negro', 'Salta', 'San Juan', 'San Luis', 'Santa Cruz',
#        'Santa Fe', 'Santiago Del Estero', 'Tierra Del Fuego', 'TucumÃ¡n'],
#       dtype=object)

# %% [markdown]
# ## Cambiando valores no entendibles de la columna Provincia, por valores legibles.

# %%
cambioNombre ={'CÃ³rdoba': 'Cordoba', 'Entre RÃ\xados': 'Entre Rancho', 'NeuquÃ©n': 'Neuquen', 'RÃ\xado Negro': 'Ramncho Negro', 'TucumÃ¡n': 'Tucuman'}
AccesoInternet['Provincia'] = AccesoInternet['Provincia'].replace(cambioNombre)
valoresUnicos = AccesoInternet['Provincia'].unique()
valoresUnicos
# Out:
# array(['Buenos Aires', 'Cordoba', 'Capital Federal', 'Catamarca', 'Chaco',
#        'Chubut', 'Corrientes', 'Entre Rancho', 'Formosa', 'Jujuy',
#        'La Pampa', 'La Rioja', 'Mendoza', 'Misiones', 'Neuquen',
#        'Ramncho Negro', 'Salta', 'San Juan', 'San Luis', 'Santa Cruz',
#        'Santa Fe', 'Santiago Del Estero', 'Tierra Del Fuego', 'Tucuman'],
#       dtype=object)

# %%
AccesoInternet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Anio                   864 non-null    int64
#  1   Trimestre              864 non-null    int64
#  2   AnioTrimestre          864 non-null    int64
#  3   Provincia              864 non-null    object
#  4   AccesoCada100Hogares   864 non-null    float64
#  5   DiferenciaTrimestral   864 non-null    float64
#  6   PorcientoTrimestral    864 non-null    float64
#  7   Cumple2                864 non-null    int64
#  8   BandAnchaFija          864 non-null    int64
#  9   Dial_up                862 non-null    float64
#  10  ADSL                   864 non-null    int64
#  11  Cablemodem             864 non-null    int64
#  12  FibraOptica            864 non-null    int64
#  13  Wireless               864 non-null    int64
# ...

# %% [markdown]
# ## Observando cuantos ceros por columnas.

# %%
ceros = ((AccesoInternet['AccesoCada100Hogares']==0).sum(),
         (AccesoInternet['BandAnchaFija']==0).sum(),
         (AccesoInternet['Dial_up']==0).sum(),
         (AccesoInternet['ADSL']==0).sum(),
         (AccesoInternet['Cablemodem']==0).sum(),
         (AccesoInternet['FibraOptica']==0).sum(),
         (AccesoInternet['Wireless']==0).sum(),
         (AccesoInternet['OtrosTipoConexion']==0).sum(),
         (AccesoInternet['totalServicios']==0).sum(),
         (AccesoInternet['Mbps(Media de bajada)']==0).sum(),
         (AccesoInternet['Hasta512kbps']==0).sum(),
         (AccesoInternet['512Kbps_Menos1Mbps']==0).sum(),
         (AccesoInternet['1Mbps_Menos6Mbps']==0).sum(),
         (AccesoInternet['6Mbps_Menos10Mbps']==0).sum(),
         (AccesoInternet['10Mbps_Menos20Mbps']==0).sum(),
         (AccesoInternet['20Mbps_Menos30Mbps']==0).sum(),
         (AccesoInternet['30Mbps']==0).sum(),
         (AccesoInternet['OtrosMbps']==0).sum(),
         (AccesoInternet['Total_Mbps']==0).sum(),
         )
ceros
# Out:
# (0, 0, 65, 0, 14, 9, 38, 0, 0, 0, 0, 50, 0, 38, 71, 104, 112, 452, 0)

# %% [markdown]
# ## Observando como quedo el DataFrame.

# %%
AccesoInternet.head()
# Out:
#    Anio  Trimestre  AnioTrimestre     Provincia  AccesoCada100Hogares  \
# 0  2022          4          20224  Buenos Aires                 78.94
# 1  2022          3          20223  Buenos Aires                 78.11
# 2  2022          2          20222  Buenos Aires                 77.58
# 3  2022          1          20221  Buenos Aires                 76.08
# 4  2021          4          20214  Buenos Aires                 75.66
#
#    DiferenciaTrimestral  PorcientoTrimestral  Cumple2  BandAnchaFija  Dial_up  \
# 0                  0.83                 1.05        0              5      6.0
# 1                  0.53                 0.68        0              5      6.0
# 2                  1.50                 1.93        0              5      6.0
# 3                  0.42                 0.55        0              5      6.0
# 4                  3.98                 5.26        1              5      6.0
#
#    ...  Mbps(Media de bajada)  Hasta512kbps  512Kbps_Menos1Mbps  \
# ...

# %% [markdown]
# ## Guardando DataFrame en un .parquet

# %%
AccesoInternet.to_parquet(r'C:\Users\ingju\Desktop\JrPs_PI2\data\etl\01_ETL_AccesoInternet.parquet')

# %% [markdown]
# ## Creando DataFrame con el archivo parquet.

# %%
internet = pd.DataFrame(pd.read_parquet(r'C:\Users\ingju\Desktop\JrPs_PI2\data\etl\01_ETL_AccesoInternet.parquet'))
internet
# Out:
#      Anio  Trimestre  AnioTrimestre     Provincia  AccesoCada100Hogares  \
# 0    2022          4          20224  Buenos Aires                 78.94
# 1    2022          3          20223  Buenos Aires                 78.11
# 2    2022          2          20222  Buenos Aires                 77.58
# 3    2022          1          20221  Buenos Aires                 76.08
# 4    2021          4          20214  Buenos Aires                 75.66
# ..    ...        ...            ...           ...                   ...
# 859  2015          1          20151       Tucuman                 35.08
# 860  2014          4          20144       Tucuman                 35.32
# 861  2014          3          20143       Tucuman                 33.94
# 862  2014          2          20142       Tucuman                 33.94
# 863  2014          1          20141       Tucuman                 33.42
#
#      DiferenciaTrimestral  PorcientoTrimestral  Cumple2  BandAnchaFija  \
# ...

# %% [markdown]
# ## Almacenando la instancia que contiene mi DataFrame.

# %%
# %store internet
# Out:
# Stored 'internet' (DataFrame)

# %% [markdown]
# ## Liberando Memoria.

# %%
del url, response, datos, df, AccesoInternet
